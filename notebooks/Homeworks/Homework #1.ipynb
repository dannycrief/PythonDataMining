# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/countryLockdownDatesJHUMatch.csv')

# %%
df.shape
# Out:
# (200, 4)

# %%
df.head(15)
# Out:
#     Country/Region        Date     Type  \
# 0   Mainland China  2020-01-23     Full
# 1        Hong Kong  2020-03-23     Full
# 2            Macau  2020-01-26     Full
# 3           Taiwan  2020-02-02     Full
# 4               US  2020-03-23  Partial
# 5            Japan  2020-02-27     Full
# 6         Thailand  2020-03-22  Partial
# 7      South Korea  2020-02-23     Full
# 8        Singapore  2020-03-26  Partial
# 9      Philippines  2020-03-16  Partial
# 10        Malaysia  2020-03-18     Full
# 11         Vietnam  2020-03-19     Full
# 12       Australia  2020-03-25  Partial
# 13          Mexico  2020-03-14  Partial
# 14          Brazil         NaN      NaN
#
#                                             Reference
# 0   https://en.wikipedia.org/wiki/2019%E2%80%9320_...
# 1   https://en.wikipedia.org/wiki/2020_coronavirus...
# 2   https://en.wikipedia.org/wiki/2020_coronavirus...
# 3   https://en.wikipedia.org/wiki/2020_coronavirus...
# ...

# %%
# covert values in column Date to datetime format and then get get weekday name
df['day_of_the_week'] = pd.to_datetime(df['Date']).dt.day_name()

# %%
df.dropna(inplace=True) #drop rows with missing values
df
# Out:
#      Country/Region        Date     Type  \
# 0    Mainland China  2020-01-23     Full
# 1         Hong Kong  2020-03-23     Full
# 2             Macau  2020-01-26     Full
# 3            Taiwan  2020-02-02     Full
# 4                US  2020-03-23  Partial
# ..              ...         ...      ...
# 168      Montenegro  2020-03-24     Full
# 170      Kyrgyzstan  2020-03-24  Partial
# 171       Mauritius  2020-03-17  Partial
# 187          Uganda  2020-03-18     Full
# 197            Mali  2020-03-18     Full
#
#                                              Reference day_of_the_week
# 0    https://en.wikipedia.org/wiki/2019%E2%80%9320_...        Thursday
# 1    https://en.wikipedia.org/wiki/2020_coronavirus...          Monday
# 2    https://en.wikipedia.org/wiki/2020_coronavirus...          Sunday
# 3    https://en.wikipedia.org/wiki/2020_coronavirus...          Sunday
# 4    https://en.wikipedia.org/wiki/2020_coronavirus...          Monday
# ...
